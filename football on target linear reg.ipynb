# %% [markdown]
# # Football On Target prediction

# %% [markdown]
# ### read and cleaning the data

# %%
import pandas as pd
df=pd.read_csv("football Data.csv")
df
# Out:
#           Country      League   Club       Player Names  Matches_Played  \
# 0           Spain     La Liga  (BET)    Juanmi Callejon              19
# 1           Spain     La Liga  (BAR)  Antoine Griezmann              36
# 2           Spain     La Liga  (ATL)        Luis Suarez              34
# 3           Spain     La Liga  (CAR)       Ruben Castro              32
# 4           Spain     La Liga  (VAL)      Kevin Gameiro              21
# ..            ...         ...    ...                ...             ...
# 655   Netherlands  Eredivisie  (UTR)        Gyrano Kerk              24
# 656   Netherlands  Eredivisie  (AJA)      Quincy Promes              18
# 657   Netherlands  Eredivisie  (PSV)    Denzel Dumfries              25
# 658   Netherlands  Eredivisie    NaN    Cyriel Dessers               26
# 659   Netherlands  Eredivisie  (PSV)         Cody Gakpo              14
#
#      Substitution   Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  660 non-null    object
#  1   League                   660 non-null    object
#  2   Club                     626 non-null    object
#  3   Player Names             660 non-null    object
#  4   Matches_Played           660 non-null    int64
#  5   Substitution             660 non-null    int64
#  6   Mins                     660 non-null    int64
#  7   Goals                    660 non-null    int64
#  8   xG                       660 non-null    float64
#  9   xG Per Avg Match         660 non-null    float64
#  10  Shots                    660 non-null    int64
#  11  OnTarget                 660 non-null    int64
#  12  Shots Per Avg Match      660 non-null    float64
#  13  On Target Per Avg Match  660 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Matches_Played  Substitution          Mins       Goals          xG  \
# count      660.000000     660.000000   660.000000  660.000000  660.000000
# mean        22.371212       3.224242  2071.416667   11.784848   10.089606
# std          9.754658       3.839498   900.595049    5.982454    5.724844
# min          2.000000       0.000000   264.000000    2.000000    0.710000
# 25%         14.000000       0.000000  1363.500000    8.000000    6.100000
# 50%         24.000000       2.000000  2245.500000   11.000000    9.285000
# 75%         31.000000       5.000000  2822.000000   14.000000   13.252500
# max         38.000000      26.000000  4177.000000   37.000000   32.540000
#
#        xG Per Avg Match       Shots    OnTarget  Shots Per Avg Match  \
# count        660.000000  660.000000  660.000000           660.000000
# mean           0.476167   64.177273   28.365152             2.948015
# std            0.192831   34.941622   16.363149             0.914906
# ...

# %%
df.isnull().sum()
# Out:
# Country                     0
# League                      0
# Club                       34
# Player Names                0
# Matches_Played              0
# Substitution                0
# Mins                        0
# Goals                       0
# xG                          0
# xG Per Avg Match            0
# Shots                       0
# OnTarget                    0
# Shots Per Avg Match         0
# On Target Per Avg Match     0
# Year                        0
# dtype: int64

# %%
df1=df.drop(columns=['Club'])
df1.isnull().sum()
df1
# Out:
#           Country      League       Player Names  Matches_Played  \
# 0           Spain     La Liga    Juanmi Callejon              19
# 1           Spain     La Liga  Antoine Griezmann              36
# 2           Spain     La Liga        Luis Suarez              34
# 3           Spain     La Liga       Ruben Castro              32
# 4           Spain     La Liga      Kevin Gameiro              21
# ..            ...         ...                ...             ...
# 655   Netherlands  Eredivisie        Gyrano Kerk              24
# 656   Netherlands  Eredivisie      Quincy Promes              18
# 657   Netherlands  Eredivisie    Denzel Dumfries              25
# 658   Netherlands  Eredivisie    Cyriel Dessers               26
# 659   Netherlands  Eredivisie         Cody Gakpo              14
#
#      Substitution   Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# 0               16  1849     11   6.62              0.34     48        20
# ...

# %% [markdown]
# ### taking the inputs and setting the target

# %%
x=pd.DataFrame(df1.loc[:,"Matches_Played":"Shots Per Avg Match"])
y=df1['On Target Per Avg Match']
x
# Out:
#      Matches_Played  Substitution   Mins  Goals     xG  xG Per Avg Match  \
# 0                19             16  1849     11   6.62              0.34
# 1                36              0  3129     16  11.86              0.36
# 2                34              1  2940     28  23.21              0.75
# 3                32              3  2842     13  14.06              0.47
# 4                21             10  1745     13  10.65              0.58
# ..              ...            ...   ...    ...    ...               ...
# 655              24              0  2155     10   7.49              0.33
# 656              18              2  1573     12   9.77              0.59
# 657              25              0  2363      7   5.72              0.23
# 658              26              0  2461     15  14.51              0.56
# 659              14             11  1557      7   4.43              0.27
#
#      Shots  OnTarget  Shots Per Avg Match
# 0       48        20                 2.47
# ...

# %% [markdown]
# ## Model Building with Linear Regression

# %%
from sklearn.model_selection import train_test_split as tts
x_train,x_test,y_train,y_test=tts(x,y,test_size=0.2,random_state=42)
from sklearn.linear_model import LinearRegression
clf=LinearRegression()
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Predicting the model

# %%
y_pred=clf.predict(x_test)
y_pred
# Out:
# array([0.8102517 , 1.62707022, 1.82868789, 1.29632463, 1.65031991,
#        0.87049945, 0.97956029, 1.23826927, 1.96954533, 0.9796944 ,
#        1.23077658, 0.82215988, 0.64674737, 1.50177136, 1.34518626,
#        1.47471483, 2.663195  , 1.58854196, 1.24281854, 1.19750361,
#        0.86465366, 0.8539337 , 1.1135737 , 1.05006843, 1.10655697,
#        1.84623184, 1.27721277, 1.28213999, 1.7974335 , 1.37397921,
#        1.61315906, 1.59401851, 1.10598817, 1.09040106, 1.64379083,
#        2.184483  , 0.82453485, 0.91466681, 1.72106132, 0.91412967,
#        0.93457268, 1.13077906, 1.78695988, 1.35884951, 1.13054686,
#        1.46131777, 0.98094058, 0.92684785, 1.44095924, 0.9928256 ,
#        1.22428401, 1.4528452 , 0.8610587 , 1.28827739, 1.09748861,
#        0.71384307, 1.49216989, 0.8534538 , 0.78971401, 1.236018  ,
#        0.89266569, 1.85114703, 1.36500016, 1.85750449, 1.27666757,
#        2.57190965, 1.31555282, 1.31054274, 0.95019036, 2.08484467,
# ...

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
r2*100
# Out:
# 95.65176812877311

# %% [markdown]
# # Visualization of the model

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred)
plt.xlabel('Y tested data')
plt.ylabel('Y predicted data')
plt.title("Goals on target Avg Match")
plt.show()
